# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhangkarsaha/Data-Science/blob/main/diabetes_decisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d81f20ad-cd45-4091-8b5a-7598ac2e063a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d81f20ad-cd45-4091-8b5a-7598ac2e063a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
path = 'diabetes.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
X = df.drop("Outcome",axis=1)
Y = df["Outcome"]

# %%
corr=df.corr()
cor_target = abs(corr["Outcome"])
relevant_features = cor_target[cor_target>=0.40]
relevant_features
# Out:
# Glucose    0.466581
# Outcome    1.000000
# Name: Outcome, dtype: float64

# %%
X_new = df[['DiabetesPedigreeFunction','Pregnancies','Glucose','BMI','Age']]
X_new
# Out:
#      DiabetesPedigreeFunction  Pregnancies  Glucose   BMI  Age
# 0                       0.627            6      148  33.6   50
# 1                       0.351            1       85  26.6   31
# 2                       0.672            8      183  23.3   32
# 3                       0.167            1       89  28.1   21
# 4                       2.288            0      137  43.1   33
# ..                        ...          ...      ...   ...  ...
# 763                     0.171           10      101  32.9   63
# 764                     0.340            2      122  36.8   27
# 765                     0.245            5      121  26.2   30
# 766                     0.349            1      126  30.1   47
# 767                     0.315            1       93  30.4   23
#
# [768 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split( X_new, Y, test_size=0.3, random_state=4)

# %%
obj = DecisionTreeClassifier(criterion="entropy",splitter="best", max_depth=3)

# %%
obj = obj.fit(X_train,y_train)

# %%
yhat = obj.predict(X_test)

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, obj.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.7616387337057728
# Test set Accuracy:  0.7965367965367965

# %%
from sklearn.ensemble import VotingClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm

# %%
mm = VotingClassifier(
    estimators=[('rf', RandomForestClassifier()),
                ('svm1', svm.SVC(kernel='poly')),
                ('gnb', GaussianNB()),
                ('svm2', svm.SVC(kernel='rbf'))])

# %%
mm.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier()),
#                              ('svm1', SVC(kernel='poly')),
#                              ('gnb', GaussianNB()), ('svm2', SVC())])

# %%
yhat = mm.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, obj.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.7616387337057728
# Test set Accuracy:  0.8051948051948052
